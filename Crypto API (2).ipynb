# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 

parameters = {
  'start':'1',
  'limit':'20',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '96dc2eae-8888888888888',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-07-09T18:03:28.780Z', 'error_code': 0, 'error_message': None, 'elapsed': 23, 'credit_count': 1, 'notice': None, 'total_count': 9990}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11595, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19719728, 'total_supply': 19719728, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-07-09T18:02:00.000Z', 'quote': {'USD': {'price': 57543.14910835417, 'volume_24h': 27738862556.947952, 'volume_change_24h': -29.9066, 'percent_change_1h': -0.25968736, 'percent_change_24h': 2.23347936, 'percent_change_7d': -7.28580902, 'percent_change_30d': -17.39792736, 'percent_change_60d': -4.61172958, 'percent_change_90d': -16.96930686, 'market_cap': 1134735248680.1868, 'market_cap_dominance': 53.7099, 'fully_diluted_market_cap': 1208406131275.44, 'tvl': None, 'last_updated': '2024-07-09T18:02:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9125, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120205195.79122268, 'total_supply': 120205195.79122268, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-07-09T18:01:00.000Z', 'quote': {'USD': {'price': 3054.9584335498575, 'volume_24h': 16052571162.82888, 'volume_change_24h': -27.757, 'percent_change_1h': -0.67287575, 'percent_change_24h': 2.3256819, 'percent_change_7d': -10.69026265, 'percent_change_30d': -17.43887064, 'percent_change_60d': 5.68445211, 'percent_change_90d': -13.04204396, 'market_cap': 367221876638.90753, 'market_cap_dominance': 17.3757, 'fully_diluted_market_cap': 367221876638.91, 'tvl': None, 'last_updated': '2024-07-09T18:01:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 91205, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 112207150564.85963, 'total_supply': 1160768 ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


# to see all the columns
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
pd.json_normalize(data['data'])
# Out:
#        id           name symbol                  slug  num_market_pairs  \
# 0       1        Bitcoin    BTC               bitcoin             11595
# 1    1027       Ethereum    ETH              ethereum              9125
# 2     825    Tether USDt   USDT                tether             91205
# 3    1839            BNB    BNB                   bnb              2190
# 4    5426         Solana    SOL                solana               699
# 5    3408           USDC   USDC              usd-coin             20881
# 6      52            XRP    XRP                   xrp              1351
# 7   11419        Toncoin    TON               toncoin               453
# 8      74       Dogecoin   DOGE              dogecoin              1021
# 9    2010        Cardano    ADA               cardano              1209
# 10   1958           TRON    TRX                  tron               999
# 11   5805      Avalanche   AVAX             avalanche               750
# 12   5994      Shiba Inu   SHIB             shiba-inu               844
# 13   6636       Polkadot    DOT          polkadot-new               792
# 14   1975      Chainlink   LINK             chainlink              1812
# 15   1831   Bitcoin Cash    BCH          bitcoin-cash               903
# 16   3957   UNUS SED LEO    LEO          unus-sed-leo                48
# 17   4943            Dai    DAI  multi-collateral-dai              3339
# 18      2       Litecoin    LTC              litecoin              1207
# 19   6535  NEAR Protocol   NEAR         near-protocol               425
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2021-08-26T13:40:22.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-09-20T00:00:00.000Z
# 15  2017-07-23T00:00:00.000Z
# 16  2019-05-21T00:00:00.000Z
# 17  2019-11-22T00:00:00.000Z
# 18  2013-04-28T00:00:00.000Z
# 19  2020-08-11T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 10  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 13  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 14  [platform, defi, oracles, smart-contracts, sub...           NaN
# 15  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
# 16  [marketplace, centralized-exchange, discount-t...           NaN
# 17  [defi, stablecoin, asset-backed-stablecoin, et...           NaN
# 18        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 19  [platform, ai-big-data, staking, coinbase-vent...           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.971973e+07  1.971973e+07            False       NaN         1
# 1         1.202052e+08  1.202052e+08             True       NaN         2
# 2         1.122072e+11  1.160769e+11             True       NaN         3
# 3         1.475826e+08  1.475826e+08            False       NaN         4
# 4         4.636609e+08  5.798393e+08             True       NaN         5
# 5         3.395416e+10  3.395416e+10            False       NaN         6
# 6         5.572306e+10  9.998747e+10            False       NaN         7
# 7         2.506177e+09  5.108764e+09             True       NaN         8
# 8         1.450473e+11  1.450473e+11             True       NaN         9
# 9         3.587210e+10  3.703500e+10            False       NaN        10
# 10        8.714816e+10  8.714823e+10             True       NaN        11
# 11        3.943909e+08  4.437373e+08            False       NaN        12
# 12        5.892708e+14  5.895193e+14            False       NaN        13
# 13        1.437953e+09  1.437953e+09             True       NaN        14
# 14        6.081000e+08  1.000000e+09            False       NaN        15
# 15        1.973050e+07  1.973050e+07            False       NaN        16
# 16        9.260377e+08  9.852395e+08            False       NaN        17
# 17        5.347889e+09  5.347889e+09             True       NaN        18
# 18        7.473144e+07  8.400000e+07            False       NaN        19
# 19        1.096094e+09  1.199620e+09            False       NaN        20
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                       3.414167e+09              2.479041e+10      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                      7.165966e+10              9.282628e+09      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                      1.466835e+09              8.877502e+09      None
# 14                               NaN                       NaN      None
# 15                               NaN                       NaN      None
# 16                               NaN                       NaN      None
# 17                               NaN                       NaN      None
# 18                               NaN                       NaN      None
# 19                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-07-09T18:02:00.000Z     57543.149108          2.773886e+10
# 1   2024-07-09T18:01:00.000Z      3054.958434          1.605257e+10
# 2   2024-07-09T18:01:00.000Z         0.999955          5.382595e+10
# 3   2024-07-09T18:01:00.000Z       518.012627          1.602766e+09
# 4   2024-07-09T18:01:00.000Z       141.506321          2.581140e+09
# 5   2024-07-09T18:01:00.000Z         0.999939          5.544062e+09
# 6   2024-07-09T18:02:00.000Z         0.433195          1.009699e+09
# 7   2024-07-09T18:01:00.000Z         7.261042          2.642792e+08
# 8   2024-07-09T18:02:00.000Z         0.106970          5.951909e+08
# 9   2024-07-09T18:01:00.000Z         0.374655          2.861989e+08
# 10  2024-07-09T18:01:00.000Z         0.129538          3.068983e+08
# 11  2024-07-09T18:01:00.000Z        25.536021          3.551090e+08
# 12  2024-07-09T18:01:00.000Z         0.000016          3.061328e+08
# 13  2024-07-09T18:02:00.000Z         6.052147          2.041169e+08
# 14  2024-07-09T18:01:00.000Z        12.771307          3.785801e+08
# 15  2024-07-09T18:01:00.000Z       329.773977          2.130902e+08
# 16  2024-07-09T18:01:00.000Z         5.853764          9.583611e+05
# 17  2024-07-09T18:01:00.000Z         1.000014          8.044212e+08
# 18  2024-07-09T18:02:00.000Z        65.716682          2.392650e+08
# 19  2024-07-09T18:02:00.000Z         4.467160          2.656872e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -29.9066                    -0.259687
# 1                      -27.7570                    -0.672876
# 2                      -27.5147                    -0.024484
# 3                      -30.1601                    -0.176624
# 4                      -28.8493                    -0.823657
# 5                      -30.6145                    -0.029484
# 6                      -34.3781                    -0.280129
# 7                      -40.9807                    -0.031584
# 8                      -42.3850                    -0.828607
# 9                      -42.9950                    -0.242040
# 10                     -32.0586                     0.044744
# 11                     -18.8701                    -0.482858
# 12                     -44.9990                    -0.283056
# 13                     -20.4586                    -0.761937
# 14                     -15.9159                    -0.850812
# 15                     -25.6456                    -0.764659
# 16                      92.2505                     0.048057
# 17                      -5.4495                    -0.011599
# 18                     -39.5749                    -0.132231
# 19                     -23.3831                    -1.052508
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       2.233479                    -7.285809
# 1                       2.325682                   -10.690263
# 2                       0.017032                     0.139043
# 3                       2.529420                   -10.129012
# 4                       3.239144                    -5.627625
# 5                      -0.002639                     0.011195
# 6                       1.325337                   -10.107054
# 7                       1.220728                    -9.897040
# 8                       0.244765                   -13.213649
# 9                       2.788750                    -9.220238
# 10                      3.272580                     0.651169
# 11                     -1.409832                   -10.051470
# 12                      0.357870                    -4.820759
# 13                      1.213798                    -4.865702
# 14                     -0.656496                   -11.744212
# 15                      0.107010                   -13.321946
# 16                      1.512860                     1.206981
# 17                      0.012342                     0.020520
# 18                      1.795106                   -12.574859
# 19                     -0.391822                   -18.058532
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                     -17.397927                     -4.611730
# 1                     -17.438871                      5.684452
# 2                       0.002427                      0.006988
# 3                     -23.442792                    -11.390910
# 4                     -12.032724                     -3.406910
# 5                      -0.013656                     -0.016609
# 6                     -12.674676                    -14.058097
# 7                       2.331604                      9.489662
# 8                     -27.452958                    -25.691729
# 9                     -15.185540                    -15.968890
# 10                     10.996289                      1.688528
# 11                    -21.762000                    -25.156177
# 12                    -30.630047                    -27.346438
# 13                     -6.621646                    -10.901056
# 14                    -20.441145                     -6.068817
# 15                    -29.954695                    -22.296264
# 16                      0.724368                     -1.731327
# 17                      0.009563                      0.011100
# 18                    -18.343250                    -18.645894
# 19                    -32.261702                    -38.245926
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                     -16.969307          1.134735e+12
# 1                     -13.042044          3.672219e+11
# 2                      -0.048872          1.122021e+11
# 3                     -14.341947          7.644964e+10
# 4                     -17.241043          6.561094e+10
# 5                      -0.052332          3.395210e+10
# 6                     -29.577486          2.413896e+10
# 7                       8.900760          1.819745e+10
# 8                     -45.017556          1.551565e+10
# 9                     -35.493916          1.343965e+10
# 10                      8.924823          1.128897e+10
# 11                    -45.895207          1.007117e+10
# 12                    -41.696702          9.559290e+09
# 13                    -27.636379          8.702706e+09
# 14                    -26.007188          7.766231e+09
# 15                    -46.346369          6.506605e+09
# 16                     -2.027963          5.420806e+09
# 17                     -0.013029          5.347963e+09
# 18                    -31.806331          4.911103e+09
# 19                    -35.454922          4.896425e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          53.7099                        1.208406e+12
# 1                          17.3757                        3.672219e+11
# 2                           5.3104                        1.160716e+11
# 3                           3.6183                        7.644964e+10
# 4                           3.1053                        8.205092e+10
# 5                           1.6065                        3.395210e+10
# 6                           1.1422                        4.331951e+10
# 7                           0.8613                        3.709495e+10
# 8                           0.7341                        1.551565e+10
# 9                           0.6361                        1.685946e+10
# 10                          0.5343                        1.128898e+10
# 11                          0.4767                        1.827737e+10
# 12                          0.4524                        9.563321e+09
# 13                          0.4119                        8.702706e+09
# 14                          0.3676                        1.277131e+10
# 15                          0.3079                        6.925254e+09
# 16                          0.2566                        5.767359e+09
# 17                          0.2531                        5.347963e+09
# 18                          0.2324                        5.520201e+09
# 19                          0.2317                        5.358894e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-07-09T18:02:00.000Z          NaN           NaN
# 1           None  2024-07-09T18:01:00.000Z          NaN           NaN
# 2           None  2024-07-09T18:01:00.000Z       1027.0      Ethereum
# 3           None  2024-07-09T18:01:00.000Z          NaN           NaN
# 4           None  2024-07-09T18:01:00.000Z          NaN           NaN
# 5           None  2024-07-09T18:01:00.000Z       1027.0      Ethereum
# 6           None  2024-07-09T18:02:00.000Z          NaN           NaN
# 7           None  2024-07-09T18:01:00.000Z          NaN           NaN
# 8           None  2024-07-09T18:02:00.000Z          NaN           NaN
# 9           None  2024-07-09T18:01:00.000Z          NaN           NaN
# 10          None  2024-07-09T18:01:00.000Z          NaN           NaN
# 11          None  2024-07-09T18:01:00.000Z          NaN           NaN
# 12          None  2024-07-09T18:01:00.000Z       1027.0      Ethereum
# 13          None  2024-07-09T18:02:00.000Z          NaN           NaN
# 14          None  2024-07-09T18:01:00.000Z       1027.0      Ethereum
# 15          None  2024-07-09T18:01:00.000Z          NaN           NaN
# 16          None  2024-07-09T18:01:00.000Z       1027.0      Ethereum
# 17          None  2024-07-09T18:01:00.000Z       1027.0      Ethereum
# 18          None  2024-07-09T18:02:00.000Z          NaN           NaN
# 19          None  2024-07-09T18:02:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 15             NaN           NaN                                         NaN
# 16             ETH      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 17             ETH      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 18             NaN           NaN                                         NaN
# 19             NaN           NaN                                         NaN
